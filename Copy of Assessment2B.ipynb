# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import csv

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
# importing libraries
import pandas as pd
import glob
import os
  
# merging the files
joined_files = os.path.join("Desktop", "/content/college*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)
  
# Finally, the files are joined
df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
print(df)
# Out:
#                   Name  python  python_en  mysql  computational_thinking  \
# 0        ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 1              Chandru     0.0       20.0    0.0                     0.0
# 2    Ganesh Ramkumar R    -1.0       55.0   24.0                     6.0
# 3      Bodipudi Harini    -1.0        0.0   35.0                    -1.0
# 4            VIINU V P    -1.0      100.0   24.0                    -1.0
# ..                 ...     ...        ...    ...                     ...
# 114       KarthikeyanS    45.0        NaN    0.0                     NaN
# 115           BARATH.P    29.0        NaN    0.0                     NaN
# 116      N.Ajith kumar    82.0        NaN    0.0                     NaN
# 117       mohamed nabi     0.0        NaN    0.0                     NaN
# 118     yaser ahamed.A     0.0        NaN   27.0                     NaN
#
#      Previous Geekions  CodeKata Score  \
# 0                19400           19400
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)
#
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
import pandas as pd
df['avg_geekions'] = df[['Previous Geekions','CodeKata Score']].mean(axis=1)

#view updated DataFrame
df
# Out:
#                   Name  python  python_en  mysql  computational_thinking  \
# 0        ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 1              Chandru     0.0       20.0    0.0                     0.0
# 2    Ganesh Ramkumar R    -1.0       55.0   24.0                     6.0
# 3      Bodipudi Harini    -1.0        0.0   35.0                    -1.0
# 4            VIINU V P    -1.0      100.0   24.0                    -1.0
# ..                 ...     ...        ...    ...                     ...
# 114       KarthikeyanS    45.0        NaN    0.0                     NaN
# 115           BARATH.P    29.0        NaN    0.0                     NaN
# 116      N.Ajith kumar    82.0        NaN    0.0                     NaN
# 117       mohamed nabi     0.0        NaN    0.0                     NaN
# 118     yaser ahamed.A     0.0        NaN   27.0                     NaN
#
#      Previous Geekions  CodeKata Score  \
# 0                19400           19400
# ...

# %% [markdown]
# ###### No of students participated

# %%
# import module
import pandas as pd
  
# read CSV file
results = df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
  
# count no. of lines
print("Number of lines present:-", 
      len(results))
# Out:
# Number of lines present:- 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
import pandas as pd
df['avg_pythoneng','avg_mysql','avg_python'] = df[['python_en','mysql','python']].mean(axis=1)

#view updated DataFrame
df
# Out:
#                   Name  python  python_en  mysql  computational_thinking  \
# 0        ASHOK KUMAR K   100.0        0.0   31.0                     9.0
# 1              Chandru     0.0       20.0    0.0                     0.0
# 2    Ganesh Ramkumar R    -1.0       55.0   24.0                     6.0
# 3      Bodipudi Harini    -1.0        0.0   35.0                    -1.0
# 4            VIINU V P    -1.0      100.0   24.0                    -1.0
# ..                 ...     ...        ...    ...                     ...
# 114       KarthikeyanS    45.0        NaN    0.0                     NaN
# 115           BARATH.P    29.0        NaN    0.0                     NaN
# 116      N.Ajith kumar    82.0        NaN    0.0                     NaN
# 117       mohamed nabi     0.0        NaN    0.0                     NaN
# 118     yaser ahamed.A     0.0        NaN   27.0                     NaN
#
#      Previous Geekions  CodeKata Score  \
# 0                19400           19400
# ...

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
#importing pandas module 
import pandas as pd 
    
# making data frame 
df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
  
# five largest values in column age
df.nlargest(3, ['Rising'])
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 8            shifak N    58.0        0.0    0.0                     0.0
# 2   Ganesh Ramkumar R    -1.0       55.0   24.0                     6.0
# 18     Narasimhan Y L    -1.0       -1.0    0.0                     0.0
#
#     Previous Geekions  CodeKata Score                              Department  \
# 8                5180            8320  Electronics and Electrical Engineering
# 2                8790           10790        Computer Science and Engineering
# 18               4800            6800        Computer Science and Engineering
#
#     Rising
# 8     3140
# 2     2000
# 18    2000

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
#importing pandas module 
import pandas as pd 
    
# making data frame 
df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
  
# five largest values in column age
df.nlargest(3, ['Previous Geekions'])
# Out:
#            Name  python  python_en  mysql  computational_thinking  \
# 35    A.Dharani    82.0        NaN   20.0                     NaN
# 36  V.JEEVITHA     82.0        NaN   20.0                     NaN
# 37  HEMAVATHI.R   100.0        NaN  100.0                     NaN
#
#     Previous Geekions  CodeKata Score                        Department  \
# 35              24500           24500  Computer Science and Engineering
# 36              21740           21740  Computer Science and Engineering
# 37              19680           19680  Computer Science and Engineering
#
#     Rising
# 35       0
# 36       0
# 37       0

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
dpt = data["Department"]
score = data["CodeKata Score"]

x=[]
y=[]
x=list(score)
y=list(dpt)

plt.pie(score,labels = dpt,autopct = '%.2f%%')
plt.title('Department wise codekata performence', fontsize = 20)
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
dpt = data["Department"]
score = data["CodeKata Score"]
x=[]
y=[]
x=list(score)
y=list(dpt)
plt.barh(y, x)
 
# setting label of y-axis
plt.ylabel("department")
 
# setting label of x-axis
plt.xlabel("score")
plt.title("Department wise toppers")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
score = data["CodeKata Score"]
dpt = data["Department"]
x=[]
y=[]
x=list(dpt)
y=list(score)
plt.scatter(x,y)
plt.xlabel('department')
plt.ylabel('Total score')
plt.title('Department wise toppers')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
score = data["CodeKata Score"]
dpt = data["Department"]
x=[]
y=[]
x=list(dpt)
y=list(score)
plt.bar(x,y)
plt.xlabel('department')
plt.ylabel('Total score')
plt.title('Department wise toppers')
plt.show()

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
 
var=df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
#print(var)

sns.lineplot(x="Department",y="CodeKata Score",
 data=var)
